# %% [markdown]
# # GRAPE calculation of control fields for iSWAP implementation

# %% [markdown]
# Robert Johansson (robert@riken.jp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
from qutip import *
from qutip.control import *

# %%
T = 1
times = np.linspace(0, T, 100)

# %%
from qutip.qip.operations import iswap

U = iswap()
R = 50
H_ops = [#tensor(sigmax(), identity(2)),
         #tensor(sigmay(), identity(2)),
         #tensor(sigmaz(), identity(2)),
         #tensor(identity(2), sigmax()),
         #tensor(identity(2), sigmay()),
         #tensor(identity(2), sigmaz()),
         tensor(sigmax(), sigmax()),
         tensor(sigmay(), sigmay()),
         tensor(sigmaz(), sigmaz())]

H_labels = [#r'$u_{1x}$',
            #r'$u_{1y}$',
            #r'$u_{1z}$',
            #r'$u_{2x}$',
            #r'$u_{2y}$',
            #r'$u_{2z}$',
            r'$u_{xx}$',
            r'$u_{yy}$',
            r'$u_{zz}$',
        ]

# %%
H0 = 0 * np.pi * (tensor(sigmaz(), identity(2)) + tensor(identity(2), sigmaz()))

# %% [markdown]
# # GRAPE

# %%
from qutip.control.grape import plot_grape_control_fields, _overlap, grape_unitary_adaptive, cy_grape_unitary

# %%
from scipy.interpolate import interp1d
from qutip.ui.progressbar import TextProgressBar

# %%
u0 = np.array([np.random.rand(len(times)) * (2 * np.pi / T) * 0.01 for _ in range(len(H_ops))])

u0 = [np.convolve(np.ones(10)/10, u0[idx, :], mode='same') for idx in range(len(H_ops))]

# %%
result = cy_grape_unitary(U, H0, H_ops, R, times, u_start=u0, eps=2*np.pi/T,
                          progress_bar=TextProgressBar())
# Out:
# 10.0%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.0%. Run time:   0.96s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.50s. Est. time left: 00:00:00:03
# 40.0%. Run time:   1.86s. Est. time left: 00:00:00:02
# 50.0%. Run time:   2.17s. Est. time left: 00:00:00:02
# 60.0%. Run time:   2.49s. Est. time left: 00:00:00:01
# 70.0%. Run time:   2.89s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.24s. Est. time left: 00:00:00:00
# 90.0%. Run time:   3.60s. Est. time left: 00:00:00:00
# Total run time:   3.87s

# %%
#result = grape_unitary(U, H0, H_ops, R, times, u_start=u0, eps=2*np.pi/T,
#                       progress_bar=TextProgressBar())

# %% [markdown]
# ## Plot control fields for iSWAP gate in the presense of single-qubit tunnelling

# %%
plot_grape_control_fields(times, result.u / (2 * np.pi), H_labels, uniform_axes=True);

# %%
# compare to the analytical results
np.mean(result.u[-1,0,:]), np.mean(result.u[-1,1,:]), np.pi/(4 * T)
# Out:
# (-0.741606880880355, -0.741454444949674, 0.7853981633974483)

# %% [markdown]
# ## Fidelity

# %%
U
# Out:
# Quantum object: dims = [[2, 2], [2, 2]], shape = (4, 4), type = oper, isherm = False
# Qobj data =
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+1.j 0.+0.j]
#  [0.+0.j 0.+1.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]]

# %%
result.U_f.tidyup(1e-2)
# Out:
# Quantum object: dims = [[2, 2], [2, 2]], shape = (4, 4), type = oper, isherm = False
# Qobj data =
# [[0.9999979 +0.j         0.        +0.j         0.        +0.j
#   0.        +0.j        ]
#  [0.        +0.j         0.09360354+0.j         0.        +0.99560745j
#   0.        +0.j        ]
#  [0.        +0.j         0.        +0.99560745j 0.09360354+0.j
#   0.        +0.j        ]
#  [0.        +0.j         0.        +0.j         0.        +0.j
#   0.9999979 +0.j        ]]

# %%
_overlap(U, result.U_f).real
# Out:
# 0.9978026747071316

# %% [markdown]
# ## Test numerical integration of GRAPE pulse

# %%
c_ops = []

# %%
# U_f_numerical = propagator(result.H_t, times[-1], c_ops, args={})
U_f_numerical = propagator(result.H_t, times, c_ops, args={})

# %%
U_f_numerical[-1]
# Out:
# Quantum object: dims = [[2, 2], [2, 2]], shape = (4, 4), type = oper, isherm = False
# Qobj data =
# [[ 9.99998103e-01-1.94133577e-03j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  3.03057015e-07+1.56152544e-04j]
#  [ 0.00000000e+00+0.00000000e+00j  8.78237885e-02+1.70469742e-04j
#   -1.93383673e-03+9.96134134e-01j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j -1.93383673e-03+9.96134134e-01j
#    8.78237885e-02+1.70469742e-04j  0.00000000e+00+0.00000000e+00j]
#  [ 3.03057015e-07+1.56152544e-04j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  9.99998103e-01-1.94133577e-03j]]

# %%
_overlap(U, U_f_numerical[-1]).real
# Out:
# 0.9980661188234379

# %% [markdown]
# # Process tomography

# %% [markdown]
# ## Ideal iSWAP gate

# %%
op_basis = [[qeye(2), sigmax(), sigmay(), sigmaz()]] * 2
op_label = [["i", "x", "y", "z"]] * 2

# %%
fig = plt.figure(figsize=(8,6))

U_ideal = spre(U) * spost(U.dag())

chi = qpt(U_ideal, op_basis)

fig = qpt_plot_combined(chi, op_label, fig=fig, threshold=0.001)

# %% [markdown]
# ## iSWAP gate calculated using GRAPE

# %%
fig = plt.figure(figsize=(8,6))

U_ideal = to_super(result.U_f)

chi = qpt(U_ideal, op_basis)

fig = qpt_plot_combined(chi, op_label, fig=fig, threshold=0.001)

# %% [markdown]
# ## Versions

# %%
from qutip.ipynbtools import version_table

version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>QuTiP</td><td>4.7.1.dev0+ff9ada8</td></tr><tr><td>Numpy</td><td>1.24.0</td></tr><tr><td>SciPy</td><td>1.9.3</td></tr><tr><td>matplotlib</td><td>3.6.2</td></tr><tr><td>Cython</td><td>0.29.32</td></tr><tr><td>Number of CPUs</td><td>8</td></tr><tr><td>BLAS Info</td><td>OPENBLAS</td></tr><tr><td>IPython</td><td>8.7.0</td></tr><tr><td>Python</td><td>3.11.0 (v3.11.0:deaf509e8f, Oct 24 2022, 14:43:23) [Clang 13.0.0 (clang-1300.0.29.30)]</td></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td colspan='2'>Thu Dec 22 15:21:42 2022 CET</td></tr></table>
